# %%
import sqlite3
from sqlite3 import Error
 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn
 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT *
        FROM FACILITIES
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (0, 'Tennis Court 1', 5, 25, 10000, 200)
# (1, 'Tennis Court 2', 5, 25, 8000, 200)
# (2, 'Badminton Court', 0, 15.5, 4000, 50)
# (3, 'Table Tennis', 0, 5, 320, 10)
# (4, 'Massage Room 1', 9.9, 80, 4000, 3000)
# (5, 'Massage Room 2', 9.9, 80, 4000, 3000)
# (6, 'Squash Court', 3.5, 17.5, 5000, 80)
# (7, 'Snooker Table', 0, 5, 450, 15)
# (8, 'Pool Table', 0, 5, 400, 15)

# %%
/* Q10: Produce a list of facilities with a total revenue less than 1000.
The output of facility name and total revenue, sorted by revenue. Remember
that there's a different cost for guests and members! */
# Out:
#   File "<ipython-input-2-2aafb755bad0>", line 1
#     *(Q10:, Produce, a, list, of, facilities, with, a, total, revenue, less, than, 1000.)
#          ^
# SyntaxError: invalid syntax

# %%
conn = create_connection("sqlite_db_pythonsqlite.db")
# Out:
# 2.6.0

# %%
import pandas as pd

# %%
query='SELECT name , revenue FROM (SELECT Facilities.name , SUM( CASE WHEN memid =0 THEN slots * Facilities.guestcost ELSE slots * membercost END ) AS revenue FROM Bookings INNER JOIN Facilities ON Bookings.facid = Facilities.facid GROUP BY Facilities.name) AS agg WHERE revenue <1000 ORDER BY revenue'

# %%
cur = conn.cursor()
query1 = 'SELECT name , revenue FROM (SELECT Facilities.name , SUM( CASE WHEN memid =0 THEN slots * Facilities.guestcost ELSE slots * membercost END ) AS revenue FROM Bookings INNER JOIN Facilities ON Bookings.facid = Facilities.facid GROUP BY Facilities.name) AS agg WHERE revenue <1000 ORDER BY revenue'
cur.execute(query1)
 
rows = cur.fetchall()
 
for row in rows:
    print(row)
# Out:
# ('Table Tennis', 180)
# ('Snooker Table', 240)
# ('Pool Table', 270)

# %%
cur = conn.cursor()
query2 = 'SELECT surname , firstname, recommendedby FROM Members WHERE memid!=0 ORDER BY Members.surname'
cur.execute(query2)
 
rows = cur.fetchall()
 
for row in rows:
    print(row)
# Out:
# ('Bader', 'Florence', '9')
# ('Baker', 'Anne', '9')
# ('Baker', 'Timothy', '13')
# ('Boothe', 'Tim', '3')
# ('Butters', 'Gerald', '1')
# ('Coplin', 'Joan', '16')
# ('Crumpet', 'Erica', '2')
# ('Dare', 'Nancy', '4')
# ('Farrell', 'Jemima', '')
# ('Farrell', 'David', '')
# ('Genting', 'Matthew', '5')
# ('Hunt', 'John', '30')
# ('Jones', 'David', '4')
# ('Jones', 'Douglas', '11')
# ('Joplette', 'Janice', '1')
# ('Mackenzie', 'Anna', '1')
# ('Owen', 'Charles', '1')
# ('Pinker', 'David', '13')
# ('Purview', 'Millicent', '2')
# ('Rownam', 'Tim', '')
# ('Rumney', 'Henrietta', '20')
# ('Sarwin', 'Ramnaresh', '15')
# ('Smith', 'Darren', '')
# ('Smith', 'Tracy', '')
# ('Smith', 'Jack', '1')
# ('Smith', 'Darren', '')
# ('Stibbons', 'Ponder', '6')
# ('Tracy', 'Burton', '')
# ('Tupperware', 'Hyacinth', '')
# ('Worthington-Smyth', 'Henry', '2')

# %%
cur = conn.cursor()
query3 = 'SELECT DISTINCT name , Bookings.slots AS usage, Bookings.memid FROM Facilities INNER JOIN Bookings ON Facilities.facid = Bookings.facid GROUP BY Facilities.name, Bookings.memid'
cur.execute(query3)
 
rows = cur.fetchall()
 
for row in rows:
    print(row)
# Out:
# ('Badminton Court', 3, 0)
# ('Badminton Court', 3, 1)
# ('Badminton Court', 3, 2)
# ('Badminton Court', 3, 3)
# ('Badminton Court', 3, 5)
# ('Badminton Court', 3, 6)
# ('Badminton Court', 3, 7)
# ('Badminton Court', 3, 8)
# ('Badminton Court', 3, 9)
# ('Badminton Court', 3, 10)
# ('Badminton Court', 3, 11)
# ('Badminton Court', 3, 12)
# ('Badminton Court', 3, 13)
# ('Badminton Court', 3, 14)
# ('Badminton Court', 3, 15)
# ('Badminton Court', 3, 16)
# ('Badminton Court', 3, 17)
# ('Badminton Court', 3, 21)
# ('Badminton Court', 3, 24)
# ('Badminton Court', 3, 26)
# ('Badminton Court', 3, 29)
# ('Badminton Court', 3, 30)
# ('Badminton Court', 3, 33)
# ('Badminton Court', 3, 35)
# ('Badminton Court', 3, 36)
# ('Massage Room 1', 2, 0)
# ('Massage Room 1', 2, 1)
# ('Massage Room 1', 2, 2)
# ('Massage Room 1', 2, 3)
# ('Massage Room 1', 2, 4)
# ('Massage Room 1', 2, 5)
# ('Massage Room 1', 2, 6)
# ('Massage Room 1', 2, 7)
# ('Massage Room 1', 2, 8)
# ('Massage Room 1', 4, 9)
# ...
